# %% [markdown]
# # 260. Generative Adverserial Networks in PyTorch
#
# - GAN은 훈련하기가 매우 어려울 수 있으며 hyperparameters, activation function 및 regularization 에 매우 민감
#
# - GAN을 훈련시켜 MNIST 와 비슷한 손으로 쓴 숫자의 이미지를 생성
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
#
# - 다음의 순서로 작업
#
#     * MNIST data load
#     * Discriminator network 정의
#     * Generator network 정의
#     * 손실함수 정의
#     * Train the model
#     * 중간 출력물 저장
#     * model 저장

# %% [markdown]
# ## Data Loading
#
# - ``torchvision.datasets.MNIST``는 `[0, 1]` 사이로 scaling 되어 있음
#
# - 픽셀 값을`[0, 1]`범위에서`[-1, 1]`범위로 변환
# $$\frac{x-\mu}{\sigma}$$
# $$\mu : 0.5, \sigma : 0.5$$
#
# - Generator 가 Tanh 함수를 activation 으로 이용하여 fake image 를 생성하기 때문에 Generator 의 출력 범위에 맞추어 준다.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

composed = Compose([
                    ToTensor(), 
                    Normalize(mean=(0.5,), std=(0.5,))])

mnist = MNIST(root='data', train=True, download=True, transform=composed)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# - image 가 `[-1, 1]`범위로 변환 되었는지 확인

# %%
img, label = mnist[0]

print(img[:,10:15,10:15])

torch.min(img), torch.max(img)
# Out:
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# - denormalized (0, 1 사이의 원래 값으로 변환) 하는 helper 함수를 정의

# %%
def denorm(x):
    out = x * 0.5 + 0.5
    return out.clamp(0, 1)

# %%
denormed = denorm(img[:,10:15,10:15])

print(denormed)

torch.min(denormed), torch.max(denormed)
# Out:
# tensor([[[0.0039, 0.6039, 0.9922, 0.3529, 0.0000],
#          [0.0000, 0.5451, 0.9922, 0.7451, 0.0078],
#          [0.0000, 0.0431, 0.7451, 0.9922, 0.2745],
#          [0.0000, 0.0000, 0.1373, 0.9451, 0.8824],
#          [0.0000, 0.0000, 0.0000, 0.3176, 0.9412]]])
# (tensor(0.), tensor(0.9922))

# %%
import matplotlib.pyplot as plt

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %% [markdown]
# ### DataLoader 생성

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 100
data_loader = DataLoader(mnist, BATCH_SIZE, shuffle=True)

# %%
for img, label in data_loader:
    print(img.shape)
    plt.imshow(img[0][0], cmap='gray')
    break;
# Out:
# torch.Size([100, 1, 28, 28])

# %% [markdown]
# ## Discriminator Network 정의
#
# - 28x28 이미지를 784 크기의 벡터로 취급
# - 3 hidden layer의 간단한 Sequential model 구축
# - 이진분류 모델 - 입력 vector가 real image 입력 이미지가 진짜일 확률 출력  (1-real, 0-fake)
# - Leaky ReLU 활성 함수를 사용 (backprop 에서 0 의 기울기(경사)를 전달하는 대신 작은 음의 기울기를 전달)
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="360">

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),      # x < 0 이면 y=0.2x
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# ## Generator Network 정의
#
# - Generator 에 대한 입력은 이미지를 생성하기 위한 시드(seed)로 사용되는 latent vector
# - 3 개의 레이어로 구성된 신경망
# - 출력은 28x28 pixel 이미지로 변환될 수 있는 784 크기의 벡터
# - Generator 의 출력 레이어에 Tanh 활성화 함수를 사용
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="240" >

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %%
y = G(torch.randn(latent_size).to(device))  # 랜덤 노이즈를 G에 입력
y.shape
# Out:
# torch.Size([784])

# %%
gen_img = denorm(y.reshape((28, 28))).cpu().detach().numpy()
gen_img.shape
# Out:
# (28, 28)

# %%
plt.imshow(gen_img, cmap='gray');

# %% [markdown]
# ## Discriminator(감별자) Training
#
# - 감별자는 이진 분류 모델이므로 binary cross entropy 손실 함수를 사용
#
# ### 감별자 훈련 단계
#
# - image가 실제의 MNIST에서 제공되면 감별자는 1을 출력해야 한다.
# - 생성자(Generator)가 생성한 image인 경우 0을 출력해야 한다.
#
# - 먼저 실제 이미지 배치를 전달하고 대상 레이블을 1로 설정하여 손실을 계산
# - 그런 다음 generator 를 사용하여 가짜 이미지 배치를 생성하고 대상 레이블을 0으로 설정하여 descriminator 에 전달한 다음 손실을 계산
#
# - 두 손실을 더하고 전체 손실을 사용하여 Gradient Descent를 수행하여 Discriminator의 weight를 조정
#
# - 감별자를 훈련시키는 동안 생성자 모델의 가중치를 변경하지 않는다는 점에 유의 (`d_optimizer`는`D.parameters ()`에만 영향을 미침).

# %%
criterion = nn.BCELoss()

d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %% [markdown]
# - gradient reset 및 discriminator train helper 함수 정의

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()
    
def train_discriminator(real_images):
    # BCE loss 계산에 사용할 label 생성
    real_labels = torch.ones(BATCH_SIZE, 1).to(device)
    fake_labels = torch.zeros(BATCH_SIZE, 1).to(device)
    
    # real image를 D가 얼마나 잘 감별했는지 loss 계산
    yhats = D(real_images)    # 잘 감별했으면 모두 1
    d_loss_real = criterion(yhats, real_labels)
    real_score = yhats
    
    # fake image를 D가 얼마나 잘 감별했는지 loss 계산
    # fake image 생성
    z = torch.randn(BATCH_SIZE, latent_size).to(device)
    fake_images = G(z)
    
    yhats = D(fake_images)  # 잘 감별했으면 모두 0
    d_loss_fake = criterion(yhats, fake_labels)
    fake_score = yhats
    
    # 두 loss를 combine
    d_loss = d_loss_real + d_loss_fake
    
    reset_grad()
    d_loss.backward()
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# ## Generator Training
#
# - 생성자의 출력은 이미지이므로 **손실 함수의 일부로 감별자를 사용**하는 트릭을 사용
#
# - 작동 방식은 다음과 같다.
#
# - 우리는 생성자를 사용하여 이미지 배치를 생성하고 감별자에 전달.
#
# - target 레이블을 1, 즉 real 로 설정하여 손실을 계산. (생성자의 목표는 감별자를 속이는 것이기 때문)
#
# - 손실을 사용하여 경사 하강을 수행. 즉, 생성자의 weight 를 변경하므로 점점 더 실제 같은 이미지를 생성하게 된다.

# %%
def train_generator():
    # 가짜 image 생성 및 loss 계산
    z = torch.randn(BATCH_SIZE, latent_size).to(device)
    fake_images = G(z)
    
    labels = torch.ones(BATCH_SIZE, 1).to(device)
    g_loss = criterion(D(fake_images), labels)  # D가 속으면 모두 1 return
    
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# - 모델의 진행 상황을 육안으로 검사하기 위해 생성기의 중간 출력을 저장할 수있는 디렉토리를 생성

# %%
import os

sample_dir = "gan_samples"
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# - 생성 된 이미지를 보면서 시각적 비교에 사용할 수있는 실제 이미지 배치를 저장

# %%
from IPython.display import Image
from torchvision.utils import save_image

# real image 일부 저장
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
    
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# - 각 epoch 이 끝날 때 마다 생성된 이미지를 디스크에 저장하는 helper function 을 정의
#
# - 모델을 학습함에 따라 생성된 개별 이미지가 시간이 지남에 따라 어떻게 진화하는지 확인하기 위해 고정된 입력 벡터 세트를 generator 에 입력으로 제공

# %%
sample_vectors = torch.randn(BATCH_SIZE, latent_size).to(device)
sample_vectors.shape
# Out:
# torch.Size([100, 64])

# %%
def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = f'fake_images-{index:0=4d}.png'
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    print("Saved..", fake_fname)
    img = plt.imread((os.path.join(sample_dir, fake_fname )))
    plt.imshow(img)
    
# Before training
save_fake_images(0)
# Out:
# Saved.. fake_images-0000.png

# %% [markdown]
# ## Train
#
# - 각 epoch 마다 먼저 Discriminator 를 훈련시킨 다음 Generator 를 훈련시킨다.
# - GPU 필요

# %%
import time
st = time.time()

num_epochs = 100
total_steps = len(data_loader)

d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        images = images.reshape(BATCH_SIZE, -1).to(device) # 28*28 -> 724
        
        # 감별자 훈련 후 생성자 훈련
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print(f'Epoch [{epoch}/{num_epochs}], Step [{i+1}/{total_steps}], ' + 
                  f'd_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}, ' +
                  f'D(x): {real_score.mean():.2f}, G(x):{fake_score.mean():.2f}')
            
    save_fake_images(epoch+1)

print("Total time elapsed :", (time.time() - st) / 60)
# Out:
# Epoch [0/100], Step [200/600], d_loss: 0.0361, g_loss: 4.3368, D(x): 1.00, G(x):0.03
# Epoch [0/100], Step [400/600], d_loss: 0.0359, g_loss: 6.8777, D(x): 0.99, G(x):0.02
# Epoch [0/100], Step [600/600], d_loss: 0.0713, g_loss: 5.1885, D(x): 0.97, G(x):0.03
# Saved.. fake_images-0001.png
# Epoch [1/100], Step [200/600], d_loss: 0.0676, g_loss: 5.2700, D(x): 0.98, G(x):0.04
# Epoch [1/100], Step [400/600], d_loss: 0.3963, g_loss: 3.2950, D(x): 0.87, G(x):0.18
# Epoch [1/100], Step [600/600], d_loss: 0.3933, g_loss: 5.6510, D(x): 0.92, G(x):0.15
# Saved.. fake_images-0002.png
# Epoch [2/100], Step [200/600], d_loss: 0.2838, g_loss: 3.9690, D(x): 0.93, G(x):0.16
# Epoch [2/100], Step [400/600], d_loss: 0.3144, g_loss: 4.6848, D(x): 0.89, G(x):0.07
# Epoch [2/100], Step [600/600], d_loss: 0.6954, g_loss: 3.0111, D(x): 0.88, G(x):0.38
# Saved.. fake_images-0003.png
# Epoch [3/100], Step [200/600], d_loss: 0.4472, g_loss: 3.5214, D(x): 0.84, G(x):0.09
# Epoch [3/100], Step [400/600], d_loss: 0.6043, g_loss: 2.1589, D(x): 0.77, G(x):0.18
# Epoch [3/100], Step [600/600], d_loss: 0.2482, g_loss: 3.5868, D(x): 0.94, G(x):0.13
# Saved.. fake_images-0004.png
# Epoch [4/100], Step [200/600], d_loss: 0.3048, g_loss: 3.3810, D(x): 0.93, G(x):0.16
# Epoch [4/100], Step [400/600], d_loss: 0.9639, g_loss: 1.9747, D(x): 0.69, G(x):0.23
# Epoch [4/100], Step [600/600], d_loss: 0.5668, g_loss: 3.7121, D(x): 0.77, G(x):0.09
# Saved.. fake_images-0005.png
# Epoch [5/100], Step [200/600], d_loss: 0.9527, g_loss: 2.0753, D(x): 0.73, G(x):0.27
# Epoch [5/100], Step [400/600], d_loss: 0.5988, g_loss: 2.8231, D(x): 0.82, G(x):0.19
# Epoch [5/100], Step [600/600], d_loss: 0.4601, g_loss: 2.8502, D(x): 0.80, G(x):0.06
# Saved.. fake_images-0006.png
# Epoch [6/100], Step [200/600], d_loss: 0.1727, g_loss: 3.2968, D(x): 0.94, G(x):0.06
# Epoch [6/100], Step [400/600], d_loss: 0.2907, g_loss: 3.5408, D(x): 0.90, G(x):0.08
# Epoch [6/100], Step [600/600], d_loss: 0.1086, g_loss: 4.8242, D(x): 0.95, G(x):0.02
# Saved.. fake_images-0007.png
# Epoch [7/100], Step [200/600], d_loss: 0.2046, g_loss: 4.6354, D(x): 0.94, G(x):0.05
# Epoch [7/100], Step [400/600], d_loss: 0.0761, g_loss: 5.4631, D(x): 0.97, G(x):0.03
# Epoch [7/100], Step [600/600], d_loss: 0.0639, g_loss: 6.0912, D(x): 0.98, G(x):0.03
# Saved.. fake_images-0008.png
# Epoch [8/100], Step [200/600], d_loss: 0.1472, g_loss: 5.4936, D(x): 0.94, G(x):0.02
# Epoch [8/100], Step [400/600], d_loss: 0.1839, g_loss: 4.4748, D(x): 0.96, G(x):0.09
# Epoch [8/100], Step [600/600], d_loss: 0.0235, g_loss: 6.4322, D(x): 1.00, G(x):0.02
# Saved.. fake_images-0009.png
# Epoch [9/100], Step [200/600], d_loss: 0.1640, g_loss: 5.8275, D(x): 0.93, G(x):0.01
# Epoch [9/100], Step [400/600], d_loss: 0.1488, g_loss: 5.5738, D(x): 0.98, G(x):0.10
# Epoch [9/100], Step [600/600], d_loss: 0.1295, g_loss: 8.0745, D(x): 0.96, G(x):0.02
# Saved.. fake_images-0010.png
# Epoch [10/100], Step [200/600], d_loss: 0.1705, g_loss: 6.1225, D(x): 0.95, G(x):0.04
# Epoch [10/100], Step [400/600], d_loss: 0.2371, g_loss: 6.5724, D(x): 0.91, G(x):0.02
# Epoch [10/100], Step [600/600], d_loss: 0.2170, g_loss: 6.7561, D(x): 0.91, G(x):0.02
# Saved.. fake_images-0011.png
# Epoch [11/100], Step [200/600], d_loss: 0.0659, g_loss: 6.0524, D(x): 0.96, G(x):0.01
# Epoch [11/100], Step [400/600], d_loss: 0.1174, g_loss: 4.5680, D(x): 0.96, G(x):0.02
# Epoch [11/100], Step [600/600], d_loss: 0.2085, g_loss: 3.2340, D(x): 0.95, G(x):0.09
# Saved.. fake_images-0012.png
# Epoch [12/100], Step [200/600], d_loss: 0.1412, g_loss: 5.0085, D(x): 0.95, G(x):0.03
# Epoch [12/100], Step [400/600], d_loss: 0.1772, g_loss: 4.5186, D(x): 0.95, G(x):0.07
# Epoch [12/100], Step [600/600], d_loss: 0.2169, g_loss: 4.9973, D(x): 0.94, G(x):0.06
# Saved.. fake_images-0013.png
# Epoch [13/100], Step [200/600], d_loss: 0.3152, g_loss: 4.2790, D(x): 0.94, G(x):0.15
# Epoch [13/100], Step [400/600], d_loss: 0.4656, g_loss: 3.0780, D(x): 0.90, G(x):0.17
# Epoch [13/100], Step [600/600], d_loss: 0.3334, g_loss: 4.5042, D(x): 0.91, G(x):0.07
# Saved.. fake_images-0014.png
# Epoch [14/100], Step [200/600], d_loss: 0.3895, g_loss: 2.8224, D(x): 0.95, G(x):0.19
# Epoch [14/100], Step [400/600], d_loss: 0.2460, g_loss: 5.1147, D(x): 0.89, G(x):0.02
# Epoch [14/100], Step [600/600], d_loss: 0.2372, g_loss: 4.9127, D(x): 0.97, G(x):0.10
# Saved.. fake_images-0015.png
# Epoch [15/100], Step [200/600], d_loss: 0.1547, g_loss: 5.0062, D(x): 0.95, G(x):0.02
# Epoch [15/100], Step [400/600], d_loss: 0.2476, g_loss: 4.8432, D(x): 0.92, G(x):0.06
# Epoch [15/100], Step [600/600], d_loss: 0.1886, g_loss: 4.1133, D(x): 0.90, G(x):0.02
# Saved.. fake_images-0016.png
# Epoch [16/100], Step [200/600], d_loss: 0.4241, g_loss: 3.7542, D(x): 0.92, G(x):0.17
# Epoch [16/100], Step [400/600], d_loss: 0.4591, g_loss: 5.0018, D(x): 0.89, G(x):0.10
# Epoch [16/100], Step [600/600], d_loss: 0.3289, g_loss: 3.6532, D(x): 0.95, G(x):0.15
# Saved.. fake_images-0017.png
# Epoch [17/100], Step [200/600], d_loss: 0.2431, g_loss: 4.4599, D(x): 0.95, G(x):0.10
# Epoch [17/100], Step [400/600], d_loss: 0.5077, g_loss: 5.4643, D(x): 0.92, G(x):0.14
# Epoch [17/100], Step [600/600], d_loss: 0.3232, g_loss: 5.8370, D(x): 0.89, G(x):0.04
# Saved.. fake_images-0018.png
# Epoch [18/100], Step [200/600], d_loss: 0.3326, g_loss: 4.6531, D(x): 0.89, G(x):0.08
# Epoch [18/100], Step [400/600], d_loss: 0.2012, g_loss: 4.2294, D(x): 0.96, G(x):0.09
# Epoch [18/100], Step [600/600], d_loss: 0.1996, g_loss: 4.3290, D(x): 0.92, G(x):0.06
# Saved.. fake_images-0019.png
# Epoch [19/100], Step [200/600], d_loss: 0.4763, g_loss: 5.1634, D(x): 0.82, G(x):0.04
# Epoch [19/100], Step [400/600], d_loss: 0.3485, g_loss: 4.6901, D(x): 0.89, G(x):0.04
# Epoch [19/100], Step [600/600], d_loss: 0.1275, g_loss: 6.8267, D(x): 0.94, G(x):0.02
# Saved.. fake_images-0020.png
# Epoch [20/100], Step [200/600], d_loss: 0.2696, g_loss: 5.8208, D(x): 0.93, G(x):0.09
# Epoch [20/100], Step [400/600], d_loss: 0.3192, g_loss: 4.9331, D(x): 0.90, G(x):0.09
# Epoch [20/100], Step [600/600], d_loss: 0.3127, g_loss: 4.7112, D(x): 0.92, G(x):0.07
# Saved.. fake_images-0021.png
# Epoch [21/100], Step [200/600], d_loss: 0.2700, g_loss: 4.7837, D(x): 0.92, G(x):0.04
# Epoch [21/100], Step [400/600], d_loss: 0.2213, g_loss: 3.8161, D(x): 0.96, G(x):0.12
# Epoch [21/100], Step [600/600], d_loss: 0.4286, g_loss: 3.8150, D(x): 0.86, G(x):0.03
# Saved.. fake_images-0022.png
# Epoch [22/100], Step [200/600], d_loss: 0.3985, g_loss: 3.8981, D(x): 0.97, G(x):0.20
# Epoch [22/100], Step [400/600], d_loss: 0.3572, g_loss: 3.0152, D(x): 0.91, G(x):0.15
# Epoch [22/100], Step [600/600], d_loss: 0.4251, g_loss: 5.5951, D(x): 0.87, G(x):0.10
# Saved.. fake_images-0023.png
# Epoch [23/100], Step [200/600], d_loss: 0.4185, g_loss: 4.4614, D(x): 0.86, G(x):0.05
# Epoch [23/100], Step [400/600], d_loss: 0.4810, g_loss: 4.6675, D(x): 0.84, G(x):0.02
# Epoch [23/100], Step [600/600], d_loss: 0.2807, g_loss: 3.6366, D(x): 0.90, G(x):0.06
# Saved.. fake_images-0024.png
# Epoch [24/100], Step [200/600], d_loss: 0.4211, g_loss: 4.6264, D(x): 0.86, G(x):0.04
# Epoch [24/100], Step [400/600], d_loss: 0.2469, g_loss: 6.1572, D(x): 0.93, G(x):0.08
# Epoch [24/100], Step [600/600], d_loss: 0.3414, g_loss: 3.6950, D(x): 0.91, G(x):0.10
# Saved.. fake_images-0025.png
# Epoch [25/100], Step [200/600], d_loss: 0.4111, g_loss: 3.5640, D(x): 0.91, G(x):0.17
# Epoch [25/100], Step [400/600], d_loss: 0.2593, g_loss: 4.0935, D(x): 0.91, G(x):0.03
# Epoch [25/100], Step [600/600], d_loss: 0.2908, g_loss: 3.6945, D(x): 0.92, G(x):0.12
# Saved.. fake_images-0026.png
# Epoch [26/100], Step [200/600], d_loss: 0.4472, g_loss: 4.7042, D(x): 0.85, G(x):0.10
# Epoch [26/100], Step [400/600], d_loss: 0.4288, g_loss: 3.1860, D(x): 0.88, G(x):0.11
# Epoch [26/100], Step [600/600], d_loss: 0.2859, g_loss: 3.8445, D(x): 0.85, G(x):0.05
# Saved.. fake_images-0027.png
# Epoch [27/100], Step [200/600], d_loss: 0.3546, g_loss: 3.7628, D(x): 0.86, G(x):0.05
# Epoch [27/100], Step [400/600], d_loss: 0.6942, g_loss: 3.3075, D(x): 0.91, G(x):0.30
# Epoch [27/100], Step [600/600], d_loss: 0.4521, g_loss: 3.4221, D(x): 0.86, G(x):0.11
# Saved.. fake_images-0028.png
# Epoch [28/100], Step [200/600], d_loss: 0.4032, g_loss: 4.8192, D(x): 0.89, G(x):0.11
# Epoch [28/100], Step [400/600], d_loss: 0.3071, g_loss: 4.3175, D(x): 0.89, G(x):0.07
# Epoch [28/100], Step [600/600], d_loss: 0.2252, g_loss: 3.4420, D(x): 0.91, G(x):0.07
# Saved.. fake_images-0029.png
# Epoch [29/100], Step [200/600], d_loss: 0.3991, g_loss: 3.8803, D(x): 0.85, G(x):0.08
# Epoch [29/100], Step [400/600], d_loss: 0.2613, g_loss: 3.2753, D(x): 0.95, G(x):0.14
# Epoch [29/100], Step [600/600], d_loss: 0.3810, g_loss: 3.3553, D(x): 0.86, G(x):0.08
# Saved.. fake_images-0030.png
# Epoch [30/100], Step [200/600], d_loss: 0.4449, g_loss: 3.6486, D(x): 0.89, G(x):0.17
# Epoch [30/100], Step [400/600], d_loss: 0.4085, g_loss: 4.3800, D(x): 0.84, G(x):0.09
# Epoch [30/100], Step [600/600], d_loss: 0.4578, g_loss: 4.1526, D(x): 0.86, G(x):0.09
# Saved.. fake_images-0031.png
# Epoch [31/100], Step [200/600], d_loss: 0.4882, g_loss: 3.6946, D(x): 0.84, G(x):0.08
# Epoch [31/100], Step [400/600], d_loss: 0.2993, g_loss: 4.8203, D(x): 0.89, G(x):0.08
# Epoch [31/100], Step [600/600], d_loss: 0.2348, g_loss: 3.0276, D(x): 0.94, G(x):0.10
# Saved.. fake_images-0032.png
# Epoch [32/100], Step [200/600], d_loss: 0.3640, g_loss: 4.2894, D(x): 0.93, G(x):0.17
# Epoch [32/100], Step [400/600], d_loss: 0.4026, g_loss: 3.8250, D(x): 0.90, G(x):0.12
# Epoch [32/100], Step [600/600], d_loss: 0.4115, g_loss: 3.1974, D(x): 0.85, G(x):0.06
# Saved.. fake_images-0033.png
# Epoch [33/100], Step [200/600], d_loss: 0.2623, g_loss: 3.2289, D(x): 0.92, G(x):0.09
# Epoch [33/100], Step [400/600], d_loss: 0.4557, g_loss: 3.8525, D(x): 0.84, G(x):0.09
# Epoch [33/100], Step [600/600], d_loss: 0.7512, g_loss: 2.4132, D(x): 0.81, G(x):0.18
# Saved.. fake_images-0034.png
# Epoch [34/100], Step [200/600], d_loss: 0.4524, g_loss: 2.9006, D(x): 0.88, G(x):0.14
# Epoch [34/100], Step [400/600], d_loss: 0.4423, g_loss: 3.3655, D(x): 0.82, G(x):0.10
# Epoch [34/100], Step [600/600], d_loss: 0.4729, g_loss: 3.7796, D(x): 0.86, G(x):0.14
# Saved.. fake_images-0035.png
# Epoch [35/100], Step [200/600], d_loss: 0.6466, g_loss: 2.9335, D(x): 0.82, G(x):0.18
# Epoch [35/100], Step [400/600], d_loss: 0.6124, g_loss: 2.8135, D(x): 0.85, G(x):0.24
# Epoch [35/100], Step [600/600], d_loss: 0.4155, g_loss: 2.7231, D(x): 0.92, G(x):0.21
# Saved.. fake_images-0036.png
# Epoch [36/100], Step [200/600], d_loss: 0.4274, g_loss: 3.4208, D(x): 0.86, G(x):0.10
# Epoch [36/100], Step [400/600], d_loss: 0.3750, g_loss: 3.3419, D(x): 0.89, G(x):0.13
# Epoch [36/100], Step [600/600], d_loss: 0.6151, g_loss: 3.4121, D(x): 0.75, G(x):0.08
# Saved.. fake_images-0037.png
# Epoch [37/100], Step [200/600], d_loss: 0.3736, g_loss: 4.3291, D(x): 0.86, G(x):0.09
# Epoch [37/100], Step [400/600], d_loss: 0.4042, g_loss: 3.5461, D(x): 0.84, G(x):0.07
# Epoch [37/100], Step [600/600], d_loss: 0.4987, g_loss: 2.9662, D(x): 0.87, G(x):0.17
# Saved.. fake_images-0038.png
# Epoch [38/100], Step [200/600], d_loss: 0.6375, g_loss: 2.9385, D(x): 0.78, G(x):0.13
# Epoch [38/100], Step [400/600], d_loss: 0.6727, g_loss: 2.8189, D(x): 0.84, G(x):0.25
# Epoch [38/100], Step [600/600], d_loss: 0.5643, g_loss: 2.4993, D(x): 0.91, G(x):0.24
# Saved.. fake_images-0039.png
# Epoch [39/100], Step [200/600], d_loss: 0.6869, g_loss: 3.5953, D(x): 0.72, G(x):0.05
# Epoch [39/100], Step [400/600], d_loss: 0.5847, g_loss: 3.3837, D(x): 0.76, G(x):0.10
# Epoch [39/100], Step [600/600], d_loss: 0.2864, g_loss: 2.5564, D(x): 0.91, G(x):0.13
# Saved.. fake_images-0040.png
# Epoch [40/100], Step [200/600], d_loss: 0.4738, g_loss: 3.4121, D(x): 0.91, G(x):0.23
# Epoch [40/100], Step [400/600], d_loss: 0.4649, g_loss: 2.8818, D(x): 0.88, G(x):0.19
# Epoch [40/100], Step [600/600], d_loss: 0.4712, g_loss: 2.2984, D(x): 0.83, G(x):0.09
# Saved.. fake_images-0041.png
# Epoch [41/100], Step [200/600], d_loss: 0.3654, g_loss: 3.1676, D(x): 0.85, G(x):0.09
# Epoch [41/100], Step [400/600], d_loss: 0.4476, g_loss: 3.3154, D(x): 0.87, G(x):0.16
# Epoch [41/100], Step [600/600], d_loss: 0.4821, g_loss: 3.5061, D(x): 0.84, G(x):0.10
# Saved.. fake_images-0042.png
# Epoch [42/100], Step [200/600], d_loss: 0.3289, g_loss: 2.5560, D(x): 0.90, G(x):0.12
# Epoch [42/100], Step [400/600], d_loss: 0.4004, g_loss: 3.8177, D(x): 0.89, G(x):0.13
# Epoch [42/100], Step [600/600], d_loss: 0.5028, g_loss: 3.4793, D(x): 0.83, G(x):0.10
# Saved.. fake_images-0043.png
# Epoch [43/100], Step [200/600], d_loss: 0.3716, g_loss: 2.7118, D(x): 0.85, G(x):0.10
# Epoch [43/100], Step [400/600], d_loss: 0.6481, g_loss: 2.6536, D(x): 0.76, G(x):0.11
# Epoch [43/100], Step [600/600], d_loss: 0.4167, g_loss: 3.9252, D(x): 0.89, G(x):0.12
# Saved.. fake_images-0044.png
# Epoch [44/100], Step [200/600], d_loss: 0.3464, g_loss: 4.0969, D(x): 0.89, G(x):0.13
# Epoch [44/100], Step [400/600], d_loss: 0.5247, g_loss: 3.1997, D(x): 0.91, G(x):0.25
# Epoch [44/100], Step [600/600], d_loss: 0.4371, g_loss: 3.2353, D(x): 0.84, G(x):0.12
# Saved.. fake_images-0045.png
# Epoch [45/100], Step [200/600], d_loss: 0.6373, g_loss: 2.9279, D(x): 0.74, G(x):0.10
# Epoch [45/100], Step [400/600], d_loss: 0.7999, g_loss: 2.4968, D(x): 0.77, G(x):0.25
# Epoch [45/100], Step [600/600], d_loss: 0.4974, g_loss: 2.5912, D(x): 0.80, G(x):0.13
# Saved.. fake_images-0046.png
# Epoch [46/100], Step [200/600], d_loss: 0.5948, g_loss: 2.3055, D(x): 0.83, G(x):0.22
# Epoch [46/100], Step [400/600], d_loss: 0.5521, g_loss: 2.9005, D(x): 0.85, G(x):0.22
# Epoch [46/100], Step [600/600], d_loss: 0.4911, g_loss: 2.7982, D(x): 0.85, G(x):0.19
# Saved.. fake_images-0047.png
# Epoch [47/100], Step [200/600], d_loss: 0.5862, g_loss: 1.9780, D(x): 0.80, G(x):0.15
# Epoch [47/100], Step [400/600], d_loss: 0.4874, g_loss: 2.7862, D(x): 0.84, G(x):0.16
# Epoch [47/100], Step [600/600], d_loss: 0.5012, g_loss: 3.0180, D(x): 0.80, G(x):0.10
# Saved.. fake_images-0048.png
# Epoch [48/100], Step [200/600], d_loss: 0.6865, g_loss: 3.2809, D(x): 0.90, G(x):0.32
# Epoch [48/100], Step [400/600], d_loss: 0.7055, g_loss: 2.8802, D(x): 0.80, G(x):0.18
# Epoch [48/100], Step [600/600], d_loss: 0.5424, g_loss: 2.4734, D(x): 0.88, G(x):0.24
# Saved.. fake_images-0049.png
# Epoch [49/100], Step [200/600], d_loss: 0.6704, g_loss: 1.6740, D(x): 0.82, G(x):0.24
# Epoch [49/100], Step [400/600], d_loss: 0.6040, g_loss: 2.9617, D(x): 0.89, G(x):0.27
# Epoch [49/100], Step [600/600], d_loss: 0.5329, g_loss: 3.1327, D(x): 0.83, G(x):0.15
# Saved.. fake_images-0050.png
# Epoch [50/100], Step [200/600], d_loss: 0.4712, g_loss: 2.8289, D(x): 0.91, G(x):0.25
# Epoch [50/100], Step [400/600], d_loss: 0.4670, g_loss: 3.3962, D(x): 0.89, G(x):0.22
# Epoch [50/100], Step [600/600], d_loss: 0.7054, g_loss: 2.5567, D(x): 0.82, G(x):0.28
# Saved.. fake_images-0051.png
# Epoch [51/100], Step [200/600], d_loss: 0.5154, g_loss: 4.6131, D(x): 0.80, G(x):0.09
# Epoch [51/100], Step [400/600], d_loss: 0.7370, g_loss: 2.6409, D(x): 0.75, G(x):0.19
# Epoch [51/100], Step [600/600], d_loss: 0.4378, g_loss: 3.4689, D(x): 0.82, G(x):0.10
# Saved.. fake_images-0052.png
# Epoch [52/100], Step [200/600], d_loss: 0.3606, g_loss: 3.3686, D(x): 0.89, G(x):0.15
# Epoch [52/100], Step [400/600], d_loss: 0.3968, g_loss: 3.6878, D(x): 0.90, G(x):0.15
# Epoch [52/100], Step [600/600], d_loss: 0.4049, g_loss: 3.1593, D(x): 0.86, G(x):0.12
# Saved.. fake_images-0053.png
# Epoch [53/100], Step [200/600], d_loss: 0.6238, g_loss: 3.0705, D(x): 0.84, G(x):0.22
# Epoch [53/100], Step [400/600], d_loss: 0.4861, g_loss: 3.2722, D(x): 0.84, G(x):0.17
# Epoch [53/100], Step [600/600], d_loss: 0.3783, g_loss: 2.7817, D(x): 0.86, G(x):0.11
# Saved.. fake_images-0054.png
# Epoch [54/100], Step [200/600], d_loss: 0.5854, g_loss: 2.5101, D(x): 0.91, G(x):0.27
# Epoch [54/100], Step [400/600], d_loss: 0.5295, g_loss: 2.4156, D(x): 0.84, G(x):0.22
# Epoch [54/100], Step [600/600], d_loss: 0.8231, g_loss: 1.9613, D(x): 0.82, G(x):0.33
# Saved.. fake_images-0055.png
# Epoch [55/100], Step [200/600], d_loss: 0.6339, g_loss: 2.6117, D(x): 0.91, G(x):0.33
# Epoch [55/100], Step [400/600], d_loss: 0.6047, g_loss: 2.4758, D(x): 0.79, G(x):0.18
# Epoch [55/100], Step [600/600], d_loss: 0.4787, g_loss: 2.1362, D(x): 0.84, G(x):0.17
# Saved.. fake_images-0056.png
# Epoch [56/100], Step [200/600], d_loss: 0.5401, g_loss: 2.3696, D(x): 0.81, G(x):0.18
# Epoch [56/100], Step [400/600], d_loss: 0.6684, g_loss: 2.4976, D(x): 0.78, G(x):0.20
# Epoch [56/100], Step [600/600], d_loss: 0.5139, g_loss: 2.6622, D(x): 0.82, G(x):0.16
# Saved.. fake_images-0057.png
# Epoch [57/100], Step [200/600], d_loss: 0.5880, g_loss: 2.7559, D(x): 0.84, G(x):0.21
# Epoch [57/100], Step [400/600], d_loss: 0.6898, g_loss: 2.1059, D(x): 0.79, G(x):0.25
# Epoch [57/100], Step [600/600], d_loss: 0.8017, g_loss: 1.8220, D(x): 0.79, G(x):0.29
# Saved.. fake_images-0058.png
# Epoch [58/100], Step [200/600], d_loss: 0.7240, g_loss: 2.4226, D(x): 0.80, G(x):0.29
# Epoch [58/100], Step [400/600], d_loss: 0.8144, g_loss: 1.5268, D(x): 0.79, G(x):0.29
# Epoch [58/100], Step [600/600], d_loss: 0.5986, g_loss: 2.0684, D(x): 0.81, G(x):0.20
# Saved.. fake_images-0059.png
# Epoch [59/100], Step [200/600], d_loss: 0.8595, g_loss: 1.6613, D(x): 0.81, G(x):0.37
# Epoch [59/100], Step [400/600], d_loss: 0.5691, g_loss: 3.1625, D(x): 0.79, G(x):0.18
# Epoch [59/100], Step [600/600], d_loss: 0.6546, g_loss: 2.4969, D(x): 0.79, G(x):0.23
# Saved.. fake_images-0060.png
# Epoch [60/100], Step [200/600], d_loss: 0.5199, g_loss: 2.6599, D(x): 0.84, G(x):0.20
# Epoch [60/100], Step [400/600], d_loss: 0.6482, g_loss: 2.0161, D(x): 0.82, G(x):0.25
# Epoch [60/100], Step [600/600], d_loss: 0.6837, g_loss: 2.5633, D(x): 0.83, G(x):0.30
# Saved.. fake_images-0061.png
# Epoch [61/100], Step [200/600], d_loss: 0.5981, g_loss: 2.7929, D(x): 0.79, G(x):0.16
# Epoch [61/100], Step [400/600], d_loss: 0.6257, g_loss: 2.3298, D(x): 0.80, G(x):0.22
# Epoch [61/100], Step [600/600], d_loss: 0.7826, g_loss: 2.0802, D(x): 0.70, G(x):0.15
# Saved.. fake_images-0062.png
# Epoch [62/100], Step [200/600], d_loss: 0.5553, g_loss: 2.8517, D(x): 0.78, G(x):0.13
# Epoch [62/100], Step [400/600], d_loss: 0.4440, g_loss: 2.5368, D(x): 0.84, G(x):0.16
# Epoch [62/100], Step [600/600], d_loss: 0.6798, g_loss: 3.2165, D(x): 0.77, G(x):0.15
# Saved.. fake_images-0063.png
# Epoch [63/100], Step [200/600], d_loss: 0.5839, g_loss: 2.2116, D(x): 0.82, G(x):0.20
# Epoch [63/100], Step [400/600], d_loss: 0.5616, g_loss: 2.4646, D(x): 0.81, G(x):0.21
# Epoch [63/100], Step [600/600], d_loss: 0.7711, g_loss: 2.1739, D(x): 0.77, G(x):0.24
# Saved.. fake_images-0064.png
# Epoch [64/100], Step [200/600], d_loss: 0.9300, g_loss: 2.7258, D(x): 0.63, G(x):0.11
# Epoch [64/100], Step [400/600], d_loss: 0.5383, g_loss: 2.8031, D(x): 0.84, G(x):0.21
# Epoch [64/100], Step [600/600], d_loss: 0.4611, g_loss: 3.5386, D(x): 0.87, G(x):0.19
# Saved.. fake_images-0065.png
# Epoch [65/100], Step [200/600], d_loss: 0.5316, g_loss: 2.5204, D(x): 0.84, G(x):0.19
# Epoch [65/100], Step [400/600], d_loss: 0.5444, g_loss: 3.5256, D(x): 0.77, G(x):0.12
# Epoch [65/100], Step [600/600], d_loss: 0.5111, g_loss: 2.3171, D(x): 0.81, G(x):0.16
# Saved.. fake_images-0066.png
# Epoch [66/100], Step [200/600], d_loss: 0.3431, g_loss: 3.0904, D(x): 0.86, G(x):0.11
# Epoch [66/100], Step [400/600], d_loss: 0.5744, g_loss: 2.8972, D(x): 0.81, G(x):0.17
# Epoch [66/100], Step [600/600], d_loss: 0.6358, g_loss: 2.7616, D(x): 0.77, G(x):0.16
# Saved.. fake_images-0067.png
# Epoch [67/100], Step [200/600], d_loss: 0.4952, g_loss: 2.4638, D(x): 0.80, G(x):0.12
# Epoch [67/100], Step [400/600], d_loss: 0.4947, g_loss: 2.1530, D(x): 0.82, G(x):0.18
# Epoch [67/100], Step [600/600], d_loss: 0.6954, g_loss: 2.5072, D(x): 0.77, G(x):0.17
# Saved.. fake_images-0068.png
# Epoch [68/100], Step [200/600], d_loss: 0.6179, g_loss: 2.3965, D(x): 0.75, G(x):0.14
# Epoch [68/100], Step [400/600], d_loss: 0.6680, g_loss: 2.0441, D(x): 0.71, G(x):0.11
# Epoch [68/100], Step [600/600], d_loss: 0.7422, g_loss: 2.2233, D(x): 0.84, G(x):0.32
# Saved.. fake_images-0069.png
# Epoch [69/100], Step [200/600], d_loss: 0.5887, g_loss: 1.8539, D(x): 0.79, G(x):0.18
# Epoch [69/100], Step [400/600], d_loss: 0.8344, g_loss: 2.0597, D(x): 0.71, G(x):0.18
# Epoch [69/100], Step [600/600], d_loss: 0.6503, g_loss: 1.7996, D(x): 0.79, G(x):0.23
# Saved.. fake_images-0070.png
# Epoch [70/100], Step [200/600], d_loss: 0.6257, g_loss: 2.1635, D(x): 0.76, G(x):0.19
# Epoch [70/100], Step [400/600], d_loss: 0.6473, g_loss: 2.8788, D(x): 0.80, G(x):0.25
# Epoch [70/100], Step [600/600], d_loss: 0.6027, g_loss: 1.8846, D(x): 0.80, G(x):0.22
# Saved.. fake_images-0071.png
# Epoch [71/100], Step [200/600], d_loss: 0.8198, g_loss: 2.1244, D(x): 0.74, G(x):0.23
# Epoch [71/100], Step [400/600], d_loss: 0.6868, g_loss: 1.4221, D(x): 0.81, G(x):0.28
# Epoch [71/100], Step [600/600], d_loss: 0.6884, g_loss: 2.2770, D(x): 0.82, G(x):0.27
# Saved.. fake_images-0072.png
# Epoch [72/100], Step [200/600], d_loss: 0.6505, g_loss: 1.5254, D(x): 0.76, G(x):0.21
# Epoch [72/100], Step [400/600], d_loss: 0.7289, g_loss: 2.2510, D(x): 0.76, G(x):0.25
# Epoch [72/100], Step [600/600], d_loss: 0.8816, g_loss: 2.0938, D(x): 0.74, G(x):0.30
# Saved.. fake_images-0073.png
# Epoch [73/100], Step [200/600], d_loss: 0.9194, g_loss: 2.4009, D(x): 0.67, G(x):0.20
# Epoch [73/100], Step [400/600], d_loss: 0.8528, g_loss: 1.7431, D(x): 0.83, G(x):0.37
# Epoch [73/100], Step [600/600], d_loss: 0.8199, g_loss: 1.9686, D(x): 0.78, G(x):0.28
# Saved.. fake_images-0074.png
# Epoch [74/100], Step [200/600], d_loss: 0.8912, g_loss: 1.8609, D(x): 0.72, G(x):0.20
# Epoch [74/100], Step [400/600], d_loss: 0.5720, g_loss: 2.3308, D(x): 0.78, G(x):0.17
# Epoch [74/100], Step [600/600], d_loss: 0.6101, g_loss: 1.8817, D(x): 0.82, G(x):0.24
# Saved.. fake_images-0075.png
# Epoch [75/100], Step [200/600], d_loss: 0.6857, g_loss: 1.9677, D(x): 0.75, G(x):0.20
# Epoch [75/100], Step [400/600], d_loss: 0.6637, g_loss: 3.0550, D(x): 0.79, G(x):0.23
# Epoch [75/100], Step [600/600], d_loss: 0.6504, g_loss: 2.0228, D(x): 0.90, G(x):0.34
# Saved.. fake_images-0076.png
# Epoch [76/100], Step [200/600], d_loss: 0.6892, g_loss: 1.9760, D(x): 0.76, G(x):0.19
# Epoch [76/100], Step [400/600], d_loss: 0.5836, g_loss: 2.6698, D(x): 0.82, G(x):0.21
# Epoch [76/100], Step [600/600], d_loss: 0.7165, g_loss: 1.9566, D(x): 0.75, G(x):0.20
# Saved.. fake_images-0077.png
# Epoch [77/100], Step [200/600], d_loss: 0.8444, g_loss: 2.2634, D(x): 0.72, G(x):0.20
# Epoch [77/100], Step [400/600], d_loss: 0.6702, g_loss: 2.1879, D(x): 0.77, G(x):0.21
# Epoch [77/100], Step [600/600], d_loss: 0.6047, g_loss: 2.0143, D(x): 0.83, G(x):0.22
# Saved.. fake_images-0078.png
# Epoch [78/100], Step [200/600], d_loss: 0.6032, g_loss: 2.2059, D(x): 0.80, G(x):0.19
# Epoch [78/100], Step [400/600], d_loss: 1.0662, g_loss: 2.0775, D(x): 0.65, G(x):0.22
# Epoch [78/100], Step [600/600], d_loss: 0.7274, g_loss: 1.9545, D(x): 0.73, G(x):0.18
# Saved.. fake_images-0079.png
# Epoch [79/100], Step [200/600], d_loss: 0.8244, g_loss: 2.2011, D(x): 0.76, G(x):0.24
# Epoch [79/100], Step [400/600], d_loss: 0.7853, g_loss: 2.4228, D(x): 0.70, G(x):0.14
# Epoch [79/100], Step [600/600], d_loss: 0.8933, g_loss: 2.3005, D(x): 0.72, G(x):0.25
# Saved.. fake_images-0080.png
# Epoch [80/100], Step [200/600], d_loss: 0.7945, g_loss: 2.0594, D(x): 0.82, G(x):0.30
# Epoch [80/100], Step [400/600], d_loss: 0.7722, g_loss: 2.9734, D(x): 0.71, G(x):0.16
# Epoch [80/100], Step [600/600], d_loss: 0.5713, g_loss: 2.3368, D(x): 0.83, G(x):0.23
# Saved.. fake_images-0081.png
# Epoch [81/100], Step [200/600], d_loss: 0.8109, g_loss: 2.2517, D(x): 0.69, G(x):0.18
# Epoch [81/100], Step [400/600], d_loss: 0.8540, g_loss: 1.6984, D(x): 0.73, G(x):0.23
# Epoch [81/100], Step [600/600], d_loss: 0.6754, g_loss: 1.7921, D(x): 0.81, G(x):0.27
# Saved.. fake_images-0082.png
# Epoch [82/100], Step [200/600], d_loss: 0.7122, g_loss: 2.1431, D(x): 0.73, G(x):0.23
# Epoch [82/100], Step [400/600], d_loss: 0.9112, g_loss: 1.7617, D(x): 0.70, G(x):0.28
# Epoch [82/100], Step [600/600], d_loss: 0.6711, g_loss: 1.8538, D(x): 0.76, G(x):0.20
# Saved.. fake_images-0083.png
# Epoch [83/100], Step [200/600], d_loss: 0.8521, g_loss: 2.0161, D(x): 0.74, G(x):0.29
# Epoch [83/100], Step [400/600], d_loss: 0.5766, g_loss: 2.1263, D(x): 0.79, G(x):0.19
# Epoch [83/100], Step [600/600], d_loss: 0.9562, g_loss: 1.8008, D(x): 0.73, G(x):0.31
# Saved.. fake_images-0084.png
# Epoch [84/100], Step [200/600], d_loss: 0.7478, g_loss: 2.1807, D(x): 0.84, G(x):0.34
# Epoch [84/100], Step [400/600], d_loss: 0.7097, g_loss: 1.9532, D(x): 0.81, G(x):0.29
# Epoch [84/100], Step [600/600], d_loss: 0.9472, g_loss: 1.3853, D(x): 0.73, G(x):0.31
# Saved.. fake_images-0085.png
# Epoch [85/100], Step [200/600], d_loss: 0.6725, g_loss: 1.7930, D(x): 0.84, G(x):0.30
# Epoch [85/100], Step [400/600], d_loss: 0.6874, g_loss: 2.0819, D(x): 0.76, G(x):0.23
# Epoch [85/100], Step [600/600], d_loss: 0.9532, g_loss: 1.9711, D(x): 0.68, G(x):0.23
# Saved.. fake_images-0086.png
# Epoch [86/100], Step [200/600], d_loss: 0.6060, g_loss: 1.8791, D(x): 0.81, G(x):0.21
# Epoch [86/100], Step [400/600], d_loss: 0.7745, g_loss: 1.5849, D(x): 0.74, G(x):0.26
# Epoch [86/100], Step [600/600], d_loss: 0.8439, g_loss: 2.1927, D(x): 0.68, G(x):0.19
# Saved.. fake_images-0087.png
# Epoch [87/100], Step [200/600], d_loss: 0.7372, g_loss: 2.5530, D(x): 0.72, G(x):0.21
# Epoch [87/100], Step [400/600], d_loss: 0.8040, g_loss: 1.8198, D(x): 0.77, G(x):0.32
# Epoch [87/100], Step [600/600], d_loss: 0.9700, g_loss: 1.6462, D(x): 0.64, G(x):0.20
# Saved.. fake_images-0088.png
# Epoch [88/100], Step [200/600], d_loss: 0.7529, g_loss: 2.1237, D(x): 0.69, G(x):0.17
# Epoch [88/100], Step [400/600], d_loss: 0.6364, g_loss: 2.1900, D(x): 0.79, G(x):0.23
# Epoch [88/100], Step [600/600], d_loss: 0.8855, g_loss: 1.7028, D(x): 0.71, G(x):0.26
# Saved.. fake_images-0089.png
# Epoch [89/100], Step [200/600], d_loss: 0.7552, g_loss: 2.1871, D(x): 0.74, G(x):0.25
# Epoch [89/100], Step [400/600], d_loss: 0.6814, g_loss: 2.3995, D(x): 0.85, G(x):0.30
# Epoch [89/100], Step [600/600], d_loss: 0.8902, g_loss: 1.9215, D(x): 0.67, G(x):0.21
# Saved.. fake_images-0090.png
# Epoch [90/100], Step [200/600], d_loss: 0.8091, g_loss: 1.8073, D(x): 0.77, G(x):0.30
# Epoch [90/100], Step [400/600], d_loss: 0.8286, g_loss: 1.5030, D(x): 0.73, G(x):0.26
# Epoch [90/100], Step [600/600], d_loss: 0.7371, g_loss: 1.4293, D(x): 0.80, G(x):0.28
# Saved.. fake_images-0091.png
# Epoch [91/100], Step [200/600], d_loss: 0.6802, g_loss: 2.3328, D(x): 0.78, G(x):0.27
# Epoch [91/100], Step [400/600], d_loss: 0.8759, g_loss: 1.5165, D(x): 0.75, G(x):0.31
# Epoch [91/100], Step [600/600], d_loss: 0.8399, g_loss: 2.2488, D(x): 0.68, G(x):0.17
# Saved.. fake_images-0092.png
# Epoch [92/100], Step [200/600], d_loss: 0.6823, g_loss: 2.0700, D(x): 0.77, G(x):0.21
# Epoch [92/100], Step [400/600], d_loss: 0.8025, g_loss: 1.9083, D(x): 0.76, G(x):0.27
# Epoch [92/100], Step [600/600], d_loss: 0.7998, g_loss: 1.5181, D(x): 0.76, G(x):0.29
# Saved.. fake_images-0093.png
# Epoch [93/100], Step [200/600], d_loss: 0.5596, g_loss: 2.2441, D(x): 0.79, G(x):0.19
# Epoch [93/100], Step [400/600], d_loss: 0.8461, g_loss: 1.5080, D(x): 0.73, G(x):0.29
# Epoch [93/100], Step [600/600], d_loss: 0.8775, g_loss: 1.8843, D(x): 0.76, G(x):0.29
# Saved.. fake_images-0094.png
# Epoch [94/100], Step [200/600], d_loss: 0.8179, g_loss: 1.5677, D(x): 0.75, G(x):0.25
# Epoch [94/100], Step [400/600], d_loss: 0.7373, g_loss: 2.1820, D(x): 0.73, G(x):0.23
# Epoch [94/100], Step [600/600], d_loss: 0.6106, g_loss: 2.2630, D(x): 0.79, G(x):0.21
# Saved.. fake_images-0095.png
# Epoch [95/100], Step [200/600], d_loss: 0.7649, g_loss: 2.0592, D(x): 0.79, G(x):0.31
# Epoch [95/100], Step [400/600], d_loss: 0.6619, g_loss: 1.9646, D(x): 0.75, G(x):0.18
# Epoch [95/100], Step [600/600], d_loss: 0.7596, g_loss: 1.7048, D(x): 0.78, G(x):0.29
# Saved.. fake_images-0096.png
# Epoch [96/100], Step [200/600], d_loss: 0.7833, g_loss: 1.7541, D(x): 0.73, G(x):0.24
# Epoch [96/100], Step [400/600], d_loss: 0.7288, g_loss: 1.7213, D(x): 0.80, G(x):0.28
# Epoch [96/100], Step [600/600], d_loss: 0.8933, g_loss: 1.6374, D(x): 0.77, G(x):0.33
# Saved.. fake_images-0097.png
# Epoch [97/100], Step [200/600], d_loss: 0.9502, g_loss: 1.2288, D(x): 0.71, G(x):0.32
# Epoch [97/100], Step [400/600], d_loss: 0.8829, g_loss: 1.6533, D(x): 0.80, G(x):0.37
# Epoch [97/100], Step [600/600], d_loss: 0.8286, g_loss: 2.2754, D(x): 0.80, G(x):0.32
# Saved.. fake_images-0098.png
# Epoch [98/100], Step [200/600], d_loss: 0.8046, g_loss: 2.4023, D(x): 0.74, G(x):0.25
# Epoch [98/100], Step [400/600], d_loss: 0.6335, g_loss: 2.3722, D(x): 0.78, G(x):0.19
# Epoch [98/100], Step [600/600], d_loss: 0.7521, g_loss: 1.7775, D(x): 0.76, G(x):0.28
# Saved.. fake_images-0099.png
# Epoch [99/100], Step [200/600], d_loss: 1.0633, g_loss: 1.7073, D(x): 0.65, G(x):0.33
# Epoch [99/100], Step [400/600], d_loss: 0.7032, g_loss: 2.1882, D(x): 0.79, G(x):0.26
# Epoch [99/100], Step [600/600], d_loss: 1.1212, g_loss: 1.4145, D(x): 0.78, G(x):0.41
# Saved.. fake_images-0100.png
# Total time elapsed : 1118.753722667694

# %% [markdown]
# 모델을 학습 했으므로 checkpoint 를 저장할 수 있습니다.

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'D.ckpt')
torch.save(D.state_dict(), 'G.ckpt')

# %% [markdown]
# 10, 50, 100, 300 epoch 훈련 후 생성된 이미지가 어떻게 보이는지 보여줍니다.

# %%
Image('./gan_samples/fake_images-0010.png')

# %%
Image('./gan_samples/fake_images-0030.png')

# %%
Image('./gan_samples/fake_images-0050.png')

# %%
Image('./gan_samples/fake_images-0100.png')

# %% [markdown]
# - 처음에는 Discriminator 가 잘 구별 하므로 D 의 손실이 낮고 G 의 손실이 높지만 시간이 갈 수록 둘이 수렴하는 모습을 보여야 한다.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %% [markdown]
# - D 가 초기에는 Real 과 Fake 를 잘 감별하므로 real_score 는 1 에 fake_score 는 0 에 가깝게 시작하지만 시간이 흐를 수록 real_score 가 떨어지고 fake_score 가 올라가서 수렴하는 모양이 되어야 한다.

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
